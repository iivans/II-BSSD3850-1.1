# %%
#Import tensorflow and keras libraries
import tensorflow
import tensorflow.keras
print(tensorflow.version)
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\Isaac\\anaconda3\\envs\\Work4\\lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>

# %%
import sys
sys.version
# Out:
# '3.7.16 (default, Jan 17 2023, 16:06:28) [MSC v.1916 64 bit (AMD64)]'

# %%
a=3
b=4
b=7
a+b
# Out:
# 10

# %% [markdown]
# ### I keep my import separate because it only needs to occur once

# %%
import random

##lets say i have some large data set i loaded
a= []
for _ in range(300):
	a.append(random.randrange(20))
print(len(a))
# Out:
# 300

# %%
a[0]+a[3]
# Out:
# 28

# %%
a_orig = []
for _ in range(300):
	a_orig.append(random.randrange(20))
print(len(a_orig))

a = a_orig.copy()
a_subset = a_orig[3:50]
# Out:
# 300

# %%
a = a_orig.copy()
a_subset1 = a_orig[0:100]
a_subset2 = a_orig[100:200]
a_subset3 = a_orig[200:300]

# %%
# %who
# Out:
# a	 a_orig	 a_subset	 a_subset1	 a_subset2	 a_subset3	 b	 random	 sys
# tensorflow
